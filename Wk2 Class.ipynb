# %%
import random

#make list of 100 random integers btwn 1 and 100 (inclusive)
data_set = [random.randint(1, 100) for _ in range(100)]

#print a random number from data_set list
value = random.choice(data_set)
print(value)
# Out:
# 92

# %%
import random

#it stops at 101, so 100 is the max value
data_set = list(range (1,101))

print (random.choice(data_set))
# Out:
# 64

# %%
import math

#Example usage of math module
print(math.sqrt(16))
print(math.factorial(5))
# Out:
# 4.0
# 120

# %%
s = "spam"
s[3]
# Out:
# <function str.upper()>

# %%
s.upper()
# Out:
# 'SPAM'

# %%
x = 4
while x >0:
    x -= 1
    print(x)
# Out:
# 3
# 2
# 1
# 0

# %%
D = {}
D['name'] = 'Bob'
D['job'] = 'dev'

print(D['name'])
# Out:
# Bob

# %%
T = (1,2,3,4)
T = T + (5,6)
print(T)

#This results in an error! Tuples are immutable
T[0] = 2

#You can add to tuples (concatenation) but they are immutable so you can't go back and change what's there.
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#example 6
#use the l.append(7) list function to add a new list element of number 7 to list l

l = [1,2,3]
l2 = l

l.append(7)

print(l)
print(l2)
# Out:
# [1, 2, 3, 7]
# [1, 2, 3, 7]

# %%
#example 7
#slice a string from a longer string

s = "hiewfoiewfijo"
to_find = s.find("iew")
length = len("iew")
sliced = s[to_find:to_find+length]
print(sliced)
# Out:
# iew
