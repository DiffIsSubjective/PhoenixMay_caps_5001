# %%
# 4. nested lists
nested_list = [[1, 2, 3, 4], 
               [4, 5, "cat"], 
               [7, 8, 9]]
print(nested_list)
# Out:
# [[1, 2, 3, 4], [4, 5, 'cat'], [7, 8, 9]]

# %%
# ROWS in the list
rows = len(nested_list)
print(rows)
#COLUMNS in a list
cols = len(nested_list[0])
print(cols)
# Out:
# 3
# 4

# %%
for r in range(rows):
    l = len(nested_list[r])
    for c in range(l):
        print(f"nested_list[{r}][{c}] = {nested_list[r][c]}")
        # this error occurred 
        # EC: 2 pts of extra credit to fix the output so it 
        # doesnt error

#SOLUTION: I added a line to define variable "l", which is the length of row r. This makes it so the program
# checks how long each row is and only prints columns within that range. Now it no longer looks for indexes
# in the list that don't exist, so it prints all values without an error.
#I did not alter the list in any way. I only edited this cell.
# Out:
# nested_list[0][0] = 1
# nested_list[0][1] = 2
# nested_list[0][2] = 3
# nested_list[0][3] = 4
# nested_list[1][0] = 4
# nested_list[1][1] = 5
# nested_list[1][2] = cat
# nested_list[2][0] = 7
# nested_list[2][1] = 8
# nested_list[2][2] = 9
