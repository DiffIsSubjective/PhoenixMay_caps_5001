# %%
book = {"title": "Blood Meridian", "author": "Cormac McCarthy"}

print(book)

book["title"] = "The Road"

print(book)

# Can be modified in place
# Out:
# {'title': 'Blood Meridian', 'author': 'Cormac McCarthy'}
# {'title': 'The Road', 'author': 'Cormac McCarthy'}

# %%
nums = [1,2,3]

print(nums)

nums[0] = 5

print(nums)

# Can be modified in place
# Out:
# [1, 2, 3]
# [5, 2, 3]

# %%
hi = "Hello World"

print(hi)

hi = "W" + hi[1:]

print(hi)

# Technically cannot be modified in place, I have to re-assign the original variable to a new string
# Out:
# Hello World
# Wello World

# %%
list = [1.1]
list[0] = 4.5
print(list)
# Out:
# [4.5]

# %%
# Indexing and slicing work the same in tuples as lists

T = (5,4,3,2,1)
T[0], T[1:4] # creates a tuple with nested objects
# Out:
# (5, (4, 3, 2))

# %% [markdown]
# Write pseudo code to find the max value in the list
#
# list = [7,45,12,62,6]
#
# a = list[0]
#
# for x in list:
#     if x > a:
#         a = x

# %%
bro = [7, 45, 12, 62, 6]
max_val = bro[0]
for x in bro:
    if x > max_val:
        max_val = x
print(max_val)
# Out:
# 62

# %%
# Add virtual environment to gitignore!!!!!!
